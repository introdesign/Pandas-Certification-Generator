# %% [markdown]
# <a href="https://colab.research.google.com/github/introdesign/Pandas-Certification-Generator/blob/main/Cert_Gen.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# do simple data analysis
#
# format the date and time

# %%
# !pip install reportlab
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 10.4 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd

from reportlab.lib.pagesizes import landscape, A4
from reportlab.pdfgen import canvas
from reportlab.lib.units import inch
from reportlab.pdfbase import pdfmetrics
from reportlab.pdfbase.ttfonts import TTFont

import os

# %%
df=pd.read_excel("/content/drive/MyDrive/1.2 Python Certificate Generator Project (STARTING TEMPLATE)/dataset.xlsx")

# %%
df
# Out:
#                   Name                 Course   CourseLevel       Date
# 0   Christy Cunningham                 Python      Beginner 2023-09-10
# 1       Douglas Tucker                 PYTHON       MASTER  2023-09-11
# 2       Travis Walters                   Java  Intermediate 2023-09-12
# 3     Nathaniel Harris        Web Development      Advanced 2023-09-13
# 4                    -                    NaN      Advanced        NaT
# 5         Tonya Carter  AI & Machine Learning      Beginner 2023-09-14
# 6           Erik Smith     Mobile Development      Beginner 2023-09-15
# 7   Kristopher Johnson                 Python      Beginner 2023-09-16
# 8      Jonathan Bucker                    NaN           NaN        NaT
# 9          Robert Buck                 PYTHON       Master  2023-09-17
# 10     Joseph Mcdonald                   Java  Intermediate 2023-09-18
# 11       Jerome Abbott        Web Development      Advanced 2023-09-19
# ...

# %% [markdown]
# null value
# #from this info, we know that there are 4 columns and 11 rows(some of them are empty)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         13 non-null     object
#  1   Course       11 non-null     object
#  2   CourseLevel  12 non-null     object
#  3   Date         11 non-null     datetime64[ns]
# dtypes: datetime64[ns](1), object(3)
# memory usage: 544.0+ bytes

# %% [markdown]
# 3. Data Cleaning(Data Analysis)
# 'Data cleaning'- formatting the data before doing the cert gen logic
#
#
#
# *   Deal with missing values
# *   format the date and text

# %% [markdown]
# # 3 probelms with the original dataset (raw excel file)
#
# # 1. Inconsistency formatting in "Course" & "CourseLevel" columns - (some are capitalized but some are uppercase)
# # 2. Date Fromat (yyyy/mm/dd) --> we want to change into (dd/mm/yyyy)
# # 3. Empty rows
#
# # we are going to solve these problems using Data analysis with Pandas

# %%
df=df.dropna()

# %%
df
# Out:
#                   Name                 Course   CourseLevel       Date
# 0   Christy Cunningham                 Python      Beginner 2023-09-10
# 1       Douglas Tucker                 PYTHON       MASTER  2023-09-11
# 2       Travis Walters                   Java  Intermediate 2023-09-12
# 3     Nathaniel Harris        Web Development      Advanced 2023-09-13
# 5         Tonya Carter  AI & Machine Learning      Beginner 2023-09-14
# 6           Erik Smith     Mobile Development      Beginner 2023-09-15
# 7   Kristopher Johnson                 Python      Beginner 2023-09-16
# 9          Robert Buck                 PYTHON       Master  2023-09-17
# 10     Joseph Mcdonald                   Java  Intermediate 2023-09-18
# 11       Jerome Abbott        Web Development      Advanced 2023-09-19
# 12       William Riley  AI & Machine Learning      Beginner 2023-09-20

# %%
df["Date"]
# Out:
# 0    2023-09-10
# 1    2023-09-11
# 2    2023-09-12
# 3    2023-09-13
# 5    2023-09-14
# 6    2023-09-15
# 7    2023-09-16
# 9    2023-09-17
# 10   2023-09-18
# 11   2023-09-19
# 12   2023-09-20
# Name: Date, dtype: datetime64[ns]

# %%
df["formattedDate"]=df["Date"].dt.strftime("%d/%m/%y")
# dt--> date time
#strftime(string formatted time)--> convert datetime object into a string representation
# Out:
# <ipython-input-10-45354600f842>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["formattedDate"]=df["Date"].dt.strftime("%d/%m/%y")

# %%
df["formattedDate"]=df["Date"].dt.strftime("%d/%m/%y")
# Out:
# <ipython-input-11-32fbfdd9f165>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["formattedDate"]=df["Date"].dt.strftime("%d/%m/%y")

# %%
df
# Out:
#                   Name                 Course   CourseLevel       Date  \
# 0   Christy Cunningham                 Python      Beginner 2023-09-10
# 1       Douglas Tucker                 PYTHON       MASTER  2023-09-11
# 2       Travis Walters                   Java  Intermediate 2023-09-12
# 3     Nathaniel Harris        Web Development      Advanced 2023-09-13
# 5         Tonya Carter  AI & Machine Learning      Beginner 2023-09-14
# 6           Erik Smith     Mobile Development      Beginner 2023-09-15
# 7   Kristopher Johnson                 Python      Beginner 2023-09-16
# 9          Robert Buck                 PYTHON       Master  2023-09-17
# 10     Joseph Mcdonald                   Java  Intermediate 2023-09-18
# 11       Jerome Abbott        Web Development      Advanced 2023-09-19
# 12       William Riley  AI & Machine Learning      Beginner 2023-09-20
#
#    formattedDate
# 0       10/09/23
# 1       11/09/23
# 2       12/09/23
# 3       13/09/23
# 5       14/09/23
# ...

# %%
df
# Out:
#                   Name                 Course   CourseLevel       Date  \
# 0   Christy Cunningham                 Python      Beginner 2023-09-10
# 1       Douglas Tucker                 PYTHON       MASTER  2023-09-11
# 2       Travis Walters                   Java  Intermediate 2023-09-12
# 3     Nathaniel Harris        Web Development      Advanced 2023-09-13
# 5         Tonya Carter  AI & Machine Learning      Beginner 2023-09-14
# 6           Erik Smith     Mobile Development      Beginner 2023-09-15
# 7   Kristopher Johnson                 Python      Beginner 2023-09-16
# 9          Robert Buck                 PYTHON       Master  2023-09-17
# 10     Joseph Mcdonald                   Java  Intermediate 2023-09-18
# 11       Jerome Abbott        Web Development      Advanced 2023-09-19
# 12       William Riley  AI & Machine Learning      Beginner 2023-09-20
#
#    formattedDate
# 0       10/09/23
# 1       11/09/23
# 2       12/09/23
# 3       13/09/23
# 5       14/09/23
# ...

# %%
df=df.drop("Date",axis=1)

# %%
df
# Out:
#                   Name                 Course   CourseLevel formattedDate
# 0   Christy Cunningham                 Python      Beginner      10/09/23
# 1       Douglas Tucker                 PYTHON       MASTER       11/09/23
# 2       Travis Walters                   Java  Intermediate      12/09/23
# 3     Nathaniel Harris        Web Development      Advanced      13/09/23
# 5         Tonya Carter  AI & Machine Learning      Beginner      14/09/23
# 6           Erik Smith     Mobile Development      Beginner      15/09/23
# 7   Kristopher Johnson                 Python      Beginner      16/09/23
# 9          Robert Buck                 PYTHON       Master       17/09/23
# 10     Joseph Mcdonald                   Java  Intermediate      18/09/23
# 11       Jerome Abbott        Web Development      Advanced      19/09/23
# 12       William Riley  AI & Machine Learning      Beginner      20/09/23

# %%
# remove the "Date" column (because it is useless now)

df=df.drop("Date",axis=1)

#axis 0 = row
#axis 1 = column
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-a57fe43e7055> in <cell line: 3>()
#       1 # remove the "Date" column (because it is useless now)
#       2
# ----> 3 df=df.drop("Date",axis=1)
#       4
#       5 #axis 0 = row
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5256                 weight  1.0     0.8
#    5257         """
# -> 5258         return super().drop(
#    5259             labels=labels,
#    5260             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4547         for axis, labels in axes.items():
#    4548             if labels is not None:
# -> 4549                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4550
# ...

# %%
df
# Out:
#                   Name                 Course   CourseLevel formattedDate
# 0   Christy Cunningham                 Python      Beginner      10/09/23
# 1       Douglas Tucker                 PYTHON       MASTER       11/09/23
# 2       Travis Walters                   Java  Intermediate      12/09/23
# 3     Nathaniel Harris        Web Development      Advanced      13/09/23
# 5         Tonya Carter  AI & Machine Learning      Beginner      14/09/23
# 6           Erik Smith     Mobile Development      Beginner      15/09/23
# 7   Kristopher Johnson                 Python      Beginner      16/09/23
# 9          Robert Buck                 PYTHON       Master       17/09/23
# 10     Joseph Mcdonald                   Java  Intermediate      18/09/23
# 11       Jerome Abbott        Web Development      Advanced      19/09/23
# 12       William Riley  AI & Machine Learning      Beginner      20/09/23

# %%
# problem 1: inconsistency formatting in "Course" & "Course level" columns
df["Course"]= df["Course"].str.capitalize()
#it will broadcast the logic of capitalize() to EACH ROW

# %%
df["Course"]=df["Course"].str.capitalize()

# %%
df
# Out:
#                   Name                 Course   CourseLevel formattedDate
# 0   Christy Cunningham                 Python      Beginner      10/09/23
# 1       Douglas Tucker                 Python       MASTER       11/09/23
# 2       Travis Walters                   Java  Intermediate      12/09/23
# 3     Nathaniel Harris        Web development      Advanced      13/09/23
# 5         Tonya Carter  Ai & machine learning      Beginner      14/09/23
# 6           Erik Smith     Mobile development      Beginner      15/09/23
# 7   Kristopher Johnson                 Python      Beginner      16/09/23
# 9          Robert Buck                 Python       Master       17/09/23
# 10     Joseph Mcdonald                   Java  Intermediate      18/09/23
# 11       Jerome Abbott        Web development      Advanced      19/09/23
# 12       William Riley  Ai & machine learning      Beginner      20/09/23

# %%
df["CourseLevel"]=df["CourseLevel"].str.capitalize()

# %%
df
# Out:
#                   Name                 Course   CourseLevel formattedDate
# 0   Christy Cunningham                 Python      Beginner      10/09/23
# 1       Douglas Tucker                 Python       Master       11/09/23
# 2       Travis Walters                   Java  Intermediate      12/09/23
# 3     Nathaniel Harris        Web development      Advanced      13/09/23
# 5         Tonya Carter  Ai & machine learning      Beginner      14/09/23
# 6           Erik Smith     Mobile development      Beginner      15/09/23
# 7   Kristopher Johnson                 Python      Beginner      16/09/23
# 9          Robert Buck                 Python       Master       17/09/23
# 10     Joseph Mcdonald                   Java  Intermediate      18/09/23
# 11       Jerome Abbott        Web development      Advanced      19/09/23
# 12       William Riley  Ai & machine learning      Beginner      20/09/23

# %%
df
# Out:
#                   Name                 Course   CourseLevel formattedDate
# 0   Christy Cunningham                 Python      Beginner      10/09/23
# 1       Douglas Tucker                 Python       Master       11/09/23
# 2       Travis Walters                   Java  Intermediate      12/09/23
# 3     Nathaniel Harris        Web development      Advanced      13/09/23
# 5         Tonya Carter  Ai & machine learning      Beginner      14/09/23
# 6           Erik Smith     Mobile development      Beginner      15/09/23
# 7   Kristopher Johnson                 Python      Beginner      16/09/23
# 9          Robert Buck                 Python       Master       17/09/23
# 10     Joseph Mcdonald                   Java  Intermediate      18/09/23
# 11       Jerome Abbott        Web development      Advanced      19/09/23
# 12       William Riley  Ai & machine learning      Beginner      20/09/23

# %%
df
# Out:
#                   Name                 Course   CourseLevel formattedDate
# 0   Christy Cunningham                 Python      Beginner      10/09/23
# 1       Douglas Tucker                 Python       Master       11/09/23
# 2       Travis Walters                   Java  Intermediate      12/09/23
# 3     Nathaniel Harris        Web development      Advanced      13/09/23
# 5         Tonya Carter  Ai & machine learning      Beginner      14/09/23
# 6           Erik Smith     Mobile development      Beginner      15/09/23
# 7   Kristopher Johnson                 Python      Beginner      16/09/23
# 9          Robert Buck                 Python       Master       17/09/23
# 10     Joseph Mcdonald                   Java  Intermediate      18/09/23
# 11       Jerome Abbott        Web development      Advanced      19/09/23
# 12       William Riley  Ai & machine learning      Beginner      20/09/23

# %%
df["CourseLevel"]=df["CourseLevel"].str.capitalize()

# %%
df
# Out:
#                   Name                 Course   CourseLevel formattedDate
# 0   Christy Cunningham                 Python      Beginner      10/09/23
# 1       Douglas Tucker                 Python       Master       11/09/23
# 2       Travis Walters                   Java  Intermediate      12/09/23
# 3     Nathaniel Harris        Web development      Advanced      13/09/23
# 5         Tonya Carter  Ai & machine learning      Beginner      14/09/23
# 6           Erik Smith     Mobile development      Beginner      15/09/23
# 7   Kristopher Johnson                 Python      Beginner      16/09/23
# 9          Robert Buck                 Python       Master       17/09/23
# 10     Joseph Mcdonald                   Java  Intermediate      18/09/23
# 11       Jerome Abbott        Web development      Advanced      19/09/23
# 12       William Riley  Ai & machine learning      Beginner      20/09/23

# %% [markdown]
# # 4. Registering fonts

# %%
fonts_path="/content/drive/MyDrive/1.2 Python Certificate Generator Project (STARTING TEMPLATE)/fonts"

# %%
# register the fonts into this project
pdfmetrics.registerFont(TTFont("Lora-Bold", os.path.join(fonts_path,"Lora-Bold.ttf")))
pdfmetrics.registerFont(TTFont("Lora-Regular", os.path.join(fonts_path,"Lora-Regular.ttf")))

# %%
def certificate_generator(name,courseName,courseLevel,date):
  pdf_file_name= "/content/drive/MyDrive/1.2 Python Certificate Generator Project (STARTING TEMPLATE)/certificates/"+name+"-"+courseName+"-"+courseLevel+".pdf"

#canvas=blank screen(A4 landscape)
#
  c=canvas.Canvas(pdf_file_name,pagesize=landscape(A4))
  # the canvas' drawImage() 5 inputs
  # 1st input -- image --> what are you drawing on this empty canvas?? --> certficate template
  # 2nd input --> x axis (coordinate 0)
  # 3rd input --> y axis (coordinate 0)
  # 4th input --> width --> A4[1] --> (using the A4 variable we imported)
  # 5th input --> height --> A4[0] --> (using the A4 variable we imported)
  c.drawImage("/content/drive/MyDrive/1.2 Python Certificate Generator Project (STARTING TEMPLATE)/certificate_template.jpg",0,0,width=A4[1],height=A4[0])


  #middle of the A4 page(width)
  center_x =c._pagesize[0]/2

  #middle of the A4 page(height)
  center_y=c._pagesize[1]/2

  # 1.Name
  c.setFont("Lora-Bold",30)
  c.drawCentredString(center_x,center_y-46,name)

  #2.CourseName
  c.setFont("Lora-Bold",28)
  c.drawCentredString(center_x,center_y-105,courseName+"-"+courseLevel)

  #3.Date
  c.setFont("Lora-Bold",17)
  c.drawCentredString(center_x+190,center_y-160,date)

  #4. Cert_Id
  cert_id="Cert Id:"+str(int(pd.Timestamp.now().timestamp()))
  c.setFont("Lora-Bold",12)
  c.drawCentredString(center_x+266,center_y-230,cert_id.upper())

  c.save()

# %%
center_x=c._pagesize[0]/2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-593195343441> in <cell line: 1>()
# ----> 1 center_x=c._pagesize[0]/2
#
# NameError: name 'c' is not defined

# %%
certificate_generator("Derrick","WebDevelopment","Beginner","07/07/1991")

# %%
for index, row in df.iterrows():
  certificate_generator(row["Name"],row["Course"],row["CourseLevel"],row["formattedDate"])
